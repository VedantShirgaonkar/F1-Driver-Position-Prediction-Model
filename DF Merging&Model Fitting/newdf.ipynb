# %%
import pandas as pd

# %%
#Load Refined Datasets
circuits = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_circuits.csv')
con_res = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_con_res.csv')
con_stand = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_con_stand.csv')
constructors = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_con.csv')
driv_standings = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_driv_standings.csv')
drivers = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_drivers.csv')
laptm = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_laptm.csv')
pit_stops = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_pit_stops.csv')
qual = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_qualifying.csv')
races = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_races.csv')
results = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_results.csv')
status = pd.read_csv('/Users/rahul/Desktop/F1 Project 2/Data Cleaning/cl_status.csv')

# %%
df1 = pd.merge(races, circuits, on='circuitId', how='inner')
df1.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country
# 0     337  2010          3           Sakhir         Bahrain
# 1     338  2010          1        Melbourne       Australia
# 2     339  2010          2     Kuala Lumpur        Malaysia
# 3     340  2010         17         Shanghai           China
# 4     341  2010          4         Montmeló           Spain

# %%
df2 = pd.merge(df1, results, on='raceId', how='inner')
df2.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         4              6              3                 1            25.0
# 1        13              6              2                 2            18.0
# 2         1              1              4                 3            15.0
# 3        20              9              1                 4            12.0
# 4         3            131              5                 5            10.0
#
#    results_laps  statusId
# 0            49         1
# 1            49         1
# ...

# %%
df3 = pd.merge(df2, drivers, on='driverId', how='inner')
df3.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         4              6              3                 1            25.0
# 1        13              6              2                 2            18.0
# 2         1              1              4                 3            15.0
# 3        20              9              1                 4            12.0
# 4         3            131              5                 5            10.0
#
#    results_laps  statusId       driver_name driver_nationality driver_home  \
# ...

# %%
df4 = pd.merge(df3, constructors, on='constructorId', how='inner')
df4.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         4              6              3                 1            25.0
# 1        13              6              2                 2            18.0
# 2         1              1              4                 3            15.0
# 3        20              9              1                 4            12.0
# 4         3            131              5                 5            10.0
#
#    results_laps  statusId       driver_name driver_nationality driver_home  \
# ...

# %%
df5 = pd.merge(df4, status, on='statusId', how='left')
df5.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         4              6              3                 1            25.0
# 1        13              6              2                 2            18.0
# 2         1              1              4                 3            15.0
# 3        20              9              1                 4            12.0
# 4         3            131              5                 5            10.0
#
#    results_laps  statusId       driver_name driver_nationality driver_home  \
# ...

# %%
df6 = pd.merge(df5, qual, on=['raceId', 'driverId', 'constructorId'], how='left')
df6.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  ...  driver_home  \
# 0         4              6              3                 1  ...        Spain
# 1        13              6              2                 2  ...       Brazil
# 2         1              1              4                 3  ...           UK
# 3        20              9              1                 4  ...      Germany
# 4         3            131              5                 5  ...      Germany
#
#    driver_age  constructor_name constructor_home    status qualifyId  \
# ...

# %%
df7 = pd.merge(df6, driv_standings, on=['raceId', 'driverId'], how='left')
df7.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  ...    status  \
# 0         4              6              3                 1  ...  Finished
# 1        13              6              2                 2  ...  Finished
# 2         1              1              4                 3  ...  Finished
# 3        20              9              1                 4  ...  Finished
# 4         3            131              5                 5  ...  Finished
#
#    qualifyId  qual_position               q1               q2  \
# ...

# %%
df8 = pd.merge(df7, con_stand, on=['raceId', 'constructorId'], how='left')
df8.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  ...  \
# 0         4              6              3                 1  ...
# 1        13              6              2                 2  ...
# 2         1              1              4                 3  ...
# 3        20              9              1                 4  ...
# 4         3            131              5                 5  ...
#
#                 q2               q3  driverStandingsId driv_std_points  \
# 0  00:01:54.172000  00:01:54.608000            63737.0            25.0
# ...

# %%
df9 = pd.merge(df8, con_res, on=['raceId', 'constructorId'], how='left')
df9.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20324
# 2     337  2010          3           Sakhir         Bahrain     20325
# 3     337  2010          3           Sakhir         Bahrain     20326
# 4     337  2010          3           Sakhir         Bahrain     20327
#
#    driverId  constructorId  grid_position  results_position  ...  \
# 0         4              6              3                 1  ...
# 1        13              6              2                 2  ...
# 2         1              1              4                 3  ...
# 3        20              9              1                 4  ...
# 4         3            131              5                 5  ...
#
#    driverStandingsId  driv_std_points  driv_std_position driv_std_wins  \
# 0            63737.0             25.0                1.0           1.0
# ...

# %%
df10 = pd.merge(df9, laptm, on=['raceId', 'driverId'], how='left')
df10.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     337  2010          3           Sakhir         Bahrain     20323
# 1     337  2010          3           Sakhir         Bahrain     20323
# 2     337  2010          3           Sakhir         Bahrain     20323
# 3     337  2010          3           Sakhir         Bahrain     20323
# 4     337  2010          3           Sakhir         Bahrain     20323
#
#    driverId  constructorId  grid_position  results_position  ...  \
# 0         4              6              3                 1  ...
# 1         4              6              3                 1  ...
# 2         4              6              3                 1  ...
# 3         4              6              3                 1  ...
# 4         4              6              3                 1  ...
#
#    driv_std_wins  constructorStandingsId  con_std_points con_std_position  \
# 0            1.0                 24232.0            43.0              1.0
# ...

# %%
final_df = pd.merge(df10, pit_stops, on=['raceId', 'driverId'], how='inner')
final_df.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     841  2011          1        Melbourne       Australia     20779
# 1     841  2011          1        Melbourne       Australia     20779
# 2     841  2011          1        Melbourne       Australia     20779
# 3     841  2011          1        Melbourne       Australia     20779
# 4     841  2011          1        Melbourne       Australia     20779
#
#    driverId  constructorId  grid_position  results_position  ...  \
# 0        20              9              1                 1  ...
# 1        20              9              1                 1  ...
# 2        20              9              1                 1  ...
# 3        20              9              1                 1  ...
# 4        20              9              1                 1  ...
#
#    constructorStandingsId  con_std_points  con_std_position con_std_wins  \
# 0                 24660.0            35.0               1.0          1.0
# ...

# %%
total_duplicates = final_df.duplicated().sum()

print(f"Total duplicate rows: {total_duplicates}")
# Out:
# Total duplicate rows: 301434

# %%
pd.set_option('display.max_columns', None)
final_df.head(10)
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     841  2011          1        Melbourne       Australia     20779
# 1     841  2011          1        Melbourne       Australia     20779
# 2     841  2011          1        Melbourne       Australia     20779
# 3     841  2011          1        Melbourne       Australia     20779
# 4     841  2011          1        Melbourne       Australia     20779
# 5     841  2011          1        Melbourne       Australia     20779
# 6     841  2011          1        Melbourne       Australia     20779
# 7     841  2011          1        Melbourne       Australia     20779
# 8     841  2011          1        Melbourne       Australia     20779
# 9     841  2011          1        Melbourne       Australia     20779
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0        20              9              1                 1            25.0
# ...

# %%
final_df.shape
# Out:
# (582092, 39)

# %%
#pd.reset_option('display.max_columns')

# %%
final_df2 = final_df.loc[final_df['year']>2015]
final_df2.head()
# Out:
#         raceId  year  circuitId circuit_location circuit_country  resultId  \
# 261080     948  2016          1        Melbourne       Australia     22917
# 261081     948  2016          1        Melbourne       Australia     22917
# 261082     948  2016          1        Melbourne       Australia     22917
# 261083     948  2016          1        Melbourne       Australia     22917
# 261084     948  2016          1        Melbourne       Australia     22917
#
#         driverId  constructorId  grid_position  results_position  \
# 261080         3            131              2                 1
# 261081         3            131              2                 1
# 261082         3            131              2                 1
# 261083         3            131              2                 1
# 261084         3            131              2                 1
#
#         results_points  results_laps  statusId   driver_name  \
# ...

# %%
final_df2.shape
# Out:
# (321012, 39)

# %%
final_df2 = final_df2.reset_index(drop=True)
final_df2.head(5)
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     948  2016          1        Melbourne       Australia     22917
# 1     948  2016          1        Melbourne       Australia     22917
# 2     948  2016          1        Melbourne       Australia     22917
# 3     948  2016          1        Melbourne       Australia     22917
# 4     948  2016          1        Melbourne       Australia     22917
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         3            131              2                 1            25.0
# 1         3            131              2                 1            25.0
# 2         3            131              2                 1            25.0
# 3         3            131              2                 1            25.0
# 4         3            131              2                 1            25.0
#
#    results_laps  statusId   driver_name driver_nationality driver_home  \
# ...

# %%
total_duplicates = final_df2.duplicated().sum()

print(f"Total duplicate rows: {total_duplicates}")
# Out:
# Total duplicate rows: 152726

# %%
final_df2.drop_duplicates(inplace=True)
final_df2.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     948  2016          1        Melbourne       Australia     22917
# 2     948  2016          1        Melbourne       Australia     22917
# 4     948  2016          1        Melbourne       Australia     22917
# 6     948  2016          1        Melbourne       Australia     22917
# 8     948  2016          1        Melbourne       Australia     22917
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         3            131              2                 1            25.0
# 2         3            131              2                 1            25.0
# 4         3            131              2                 1            25.0
# 6         3            131              2                 1            25.0
# 8         3            131              2                 1            25.0
#
#    results_laps  statusId   driver_name driver_nationality driver_home  \
# ...

# %%
final_df2.shape
# Out:
# (168286, 39)

# %%
def get_weather_conditions(circuit_location, year):
    weather_data = {
    'Melbourne': {
        2016: 'Overcast', 2017: 'Overcast', 2018: 'Sunny', 2019: 'Sunny',
        2020: 'Event canceled due to COVID-19', 2021: 'Event canceled due to COVID-19', 
        2022: 'Sunny', 2023: 'Sunny'
    },
    'Sakhir': {
        2016: 'Dry', 2017: 'Dry', 2018: 'Dry', 2019: 'Dry', 
        2020: 'Dry', 2021: 'Dry', 2022: 'Dry', 2023: 'Dry'
    },
    'Shanghai': {
        2016: 'Overcast', 2017: 'Wet', 2018: 'Overcast', 2019: 'Overcast', 
        2020: 'Event canceled due to COVID-19', 2021: 'Event canceled due to COVID-19', 
        2022: 'Event canceled due to COVID-19', 2023: 'Event canceled due to COVID-19'
    },
    'Sochi': {
        2016: 'Sunny', 2017: 'Sunny', 2018: 'Overcast', 2019: 'Overcast', 
        2020: 'Overcast', 2021: 'Wet', 2022: 'Event canceled due to the Russian invasion of Ukraine',
        2023: 'Event canceled due to the Russian invasion of Ukraine'
    },
    'Montmeló': {
        2016: 'Sunny', 2017: 'Sunny', 2018: 'Sunny', 2019: 'Sunny', 
        2020: 'Sunny', 2021: 'Sunny', 2022: 'Overcast', 2023: 'Sunny'
    },
    'Monte-Carlo': {
        2016: 'Wet', 2017: 'Sunny', 2018: 'Sunny', 2019: 'Sunny', 
        2020: 'Event canceled due to COVID-19', 2021: 'Sunny', 2022: 'Wet', 2023: 'Sunny'
    },
    'Montreal': {
        2016: 'Overcast', 2017: 'Sunny', 2018: 'Sunny', 2019: 'Sunny', 
        2020: 'Event canceled due to COVID-19', 2021: 'Event canceled due to COVID-19', 
        2022: 'Overcast', 2023: 'Sunny'
    },
    'Baku': {
        2016: 'Sunny', 2017: 'Overcast', 2018: 'Overcast', 2019: 'Sunny', 
        2020: 'Event canceled due to COVID-19', 2021: 'Sunny', 2022: 'Sunny', 2023: 'Sunny'
    },
    'Spielberg': {
        2016: 'Sunny', 2017: 'Overcast', 2018: 'Sunny', 2019: 'Sunny', 
        2020: 'Sunny', 2021: 'Sunny', 2022: 'Sunny', 2023: 'Sunny'
    },
    'Silverstone': {
        2016: 'Wet', 2017: 'Overcast', 2018: 'Sunny', 2019: 'Overcast', 
        2020: 'Overcast', 2021: 'Sunny', 2022: 'Wet', 2023: 'Overcast'
    },
    'Budapest': {
        2016: 'Sunny', 2017: 'Sunny', 2018: 'Overcast', 2019: 'Sunny', 
        2020: 'Wet', 2021: 'Overcast', 2022: 'Overcast', 2023: 'Sunny'
    },
    'Hockenheim': {
        2016: 'No race', 2017: 'No race', 2018: 'Wet', 2019: 'Wet', 
        2020: 'No race', 2021: 'No race', 2022: 'No race', 2023: 'No race'
    },
    'Spa': {
        2016: 'Sunny', 2017: 'Sunny', 2018: 'Overcast', 2019: 'Overcast', 
        2020: 'Wet', 2021: 'Wet', 2022: 'Sunny', 2023: 'Sunny'
    },
    'Monza': {
        2016: 'Sunny', 2017: 'Sunny', 2018: 'Overcast', 2019: 'Sunny', 
        2020: 'Sunny', 2021: 'Sunny', 2022: 'Overcast', 2023: 'Sunny'
    },
    'Marina Bay': {
        2016: 'Overcast', 2017: 'Wet', 2018: 'Overcast', 2019: 'Overcast', 
        2020: 'Event canceled due to COVID-19', 2021: 'Event canceled due to COVID-19', 
        2022: 'Wet', 2023: 'Overcast'
    },
    'Kuala Lumpur': {
        2016: 'Sunny', 2017: 'Overcast', 2018: 'No race', 2019: 'No race',
        2020: 'No race', 2021: 'No race', 2022: 'No race', 2023: 'No race'
    },
    'Suzuka': {
        2016: 'Sunny', 2017: 'Wet', 2018: 'Overcast', 2019: 'Wet',
        2020: 'Event canceled due to COVID-19', 2021: 'Event canceled due to COVID-19', 
        2022: 'Sunny', 2023: 'Overcast'
    },
    'Austin': {
        2016: 'Overcast', 2017: 'Sunny', 2018: 'Wet', 2019: 'Overcast',
        2020: 'Overcast', 2021: 'Sunny', 2022: 'Sunny', 2023: 'Sunny'
    },
    'Mexico City': {
        2016: 'Sunny', 2017: 'Sunny', 2018: 'Overcast', 2019: 'Overcast',
        2020: 'Event canceled due to COVID-19', 2021: 'Sunny', 2022: 'Sunny', 2023: 'Sunny'
    },
    'São Paulo': {
        2016: 'Wet', 2017: 'Sunny', 2018: 'Overcast', 2019: 'Wet',
        2020: 'Event canceled due to COVID-19', 2021: 'Overcast', 2022: 'Wet', 2023: 'Sunny'
    },
    'Abu Dhabi': {
        2016: 'Dry', 2017: 'Dry', 2018: 'Dry', 2019: 'Dry',
        2020: 'Dry', 2021: 'Dry', 2022: 'Dry', 2023: 'Dry'
    },
    'Le Castellet': {
        2016: 'No race', 2017: 'No race', 2018: 'Sunny', 2019: 'Sunny',
        2020: 'Event canceled due to COVID-19', 2021: 'Sunny', 2022: 'Sunny', 2023: 'No race'
    },
    'Mugello': {
        2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
        2020: 'Sunny', 2021: 'No race', 2022: 'No race', 2023: 'No race'
    },
    'Nürburg': {
        2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
        2020: 'Wet', 2021: 'No race', 2022: 'No race', 2023: 'No race'
    },
    'Portimão': {
        2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
        2020: 'Sunny', 2021: 'Sunny', 2022: 'No race', 2023: 'No race'
    },
    'Imola': {
        2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
        2020: 'Overcast', 2021: 'Wet', 2022: 'Overcast', 2023: 'Sunny'
    },
    'Istanbul': {
    2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
    2020: 'Wet', 2021: 'Overcast', 2022: 'No race', 2023: 'No race'
    },
    'Al Daayen': {
    2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
    2020: 'No race', 2021: 'Sunny', 2022: 'Sunny', 2023: 'Sunny'
    },
    'Zandvoort': {
        2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
        2020: 'Event canceled due to COVID-19', 2021: 'Sunny', 2022: 'Sunny', 2023: 'Sunny'
    },
    'Jeddah': {
        2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
        2020: 'No race', 2021: 'Dry', 2022: 'Dry', 2023: 'Dry'
    },
    'Miami': {
        2016: 'No race', 2017: 'No race', 2018: 'No race', 2019: 'No race',
        2020: 'No race', 2021: 'No race', 2022: 'Overcast', 2023: 'Sunny'
    }
    }
    
    return weather_data.get(circuit_location, {}).get(year, 'Unknown')

# Apply the function to create the 'weather_conditions' column
final_df2['weather_conditions'] = final_df2.apply(lambda row: get_weather_conditions(row['circuit_location'], row['year']), axis=1)

# %%
final_df2.head()

# %%
final_df2.weather_conditions.unique()

# %%
# Assuming you have a DataFrame df with columns 'driver_age' and 'year'
current_year = 2023  # Adjust this value if the 'driver_age' column refers to a different year

# Calculate the age of the driver at the time of each race
final_df2['driver_age_atrace'] = final_df2['driver_age'] - (current_year - final_df2['year'])
final_df2.head()
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     948  2016          1        Melbourne       Australia     22917
# 2     948  2016          1        Melbourne       Australia     22917
# 4     948  2016          1        Melbourne       Australia     22917
# 6     948  2016          1        Melbourne       Australia     22917
# 8     948  2016          1        Melbourne       Australia     22917
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         3            131              2                 1            25.0
# 2         3            131              2                 1            25.0
# 4         3            131              2                 1            25.0
# 6         3            131              2                 1            25.0
# 8         3            131              2                 1            25.0
#
#    results_laps  statusId   driver_name driver_nationality driver_home  \
# ...

# %%
final_df2 = final_df2.loc[final_df2['weather_conditions']!='No race']
final_df2.shape
# Out:
# (166870, 41)

# %%
final_df2 = final_df2.reset_index(drop=True)
final_df2.head(10)
# Out:
#    raceId  year  circuitId circuit_location circuit_country  resultId  \
# 0     948  2016          1        Melbourne       Australia     22917
# 1     948  2016          1        Melbourne       Australia     22917
# 2     948  2016          1        Melbourne       Australia     22917
# 3     948  2016          1        Melbourne       Australia     22917
# 4     948  2016          1        Melbourne       Australia     22917
# 5     948  2016          1        Melbourne       Australia     22917
# 6     948  2016          1        Melbourne       Australia     22917
# 7     948  2016          1        Melbourne       Australia     22917
# 8     948  2016          1        Melbourne       Australia     22917
# 9     948  2016          1        Melbourne       Australia     22917
#
#    driverId  constructorId  grid_position  results_position  results_points  \
# 0         3            131              2                 1            25.0
# ...

# %%
final_df2.columns

# %%
final_df3 = final_df2[['driverId','raceId','circuit_location', 'circuit_country', 'grid_position','results_position','results_points', 'results_laps', 'driver_nationality', 'driver_home', 'driver_age_atrace', 'constructor_name', 'constructor_home', 'status', 'qual_position', 'q1', 'q2', 'q3','lap_tm_(lap)', 'lap_tm_position', 'lap_time', 'total_pit_stops','weather_conditions']]
final_df3.head()
# Out:
#    driverId  raceId circuit_location circuit_country  grid_position  \
# 0         3     948        Melbourne       Australia              2
# 1         3     948        Melbourne       Australia              2
# 2         3     948        Melbourne       Australia              2
# 3         3     948        Melbourne       Australia              2
# 4         3     948        Melbourne       Australia              2
#
#    results_position  results_points  results_laps driver_nationality  \
# 0                 1            25.0            57             German
# 1                 1            25.0            57             German
# 2                 1            25.0            57             German
# 3                 1            25.0            57             German
# 4                 1            25.0            57             German
#
#   driver_home  driver_age_atrace constructor_name constructor_home    status  \
# ...

# %%
final_df3.shape
# Out:
# (166870, 23)

# %%
final_df3.dtypes

# %%
final_df3.isnull().sum()
# Out:
# driverId                  0
# raceId                    0
# circuit_location          0
# circuit_country           0
# grid_position             0
# results_position          0
# results_points            0
# results_laps              0
# driver_nationality        0
# driver_home               0
# driver_age_atrace         0
# constructor_name          0
# constructor_home          0
# status                    0
# qual_position           499
# q1                      939
# q2                     8273
# q3                    16844
# lap_tm_(lap)              0
# lap_tm_position           0
# lap_time                  0
# total_pit_stops           0
# weather_conditions        0
# dtype: int64

# %%
with pd.option_context('mode.chained_assignment', None):
    final_df3.dropna(subset=['q3'], inplace=True)
final_df3.isnull().sum()

# %%
final_df3.shape

# %%
for column in ['q1', 'q2', 'q3','lap_time']:
    # Truncate the string to keep three decimal places
    final_df3[column] = final_df3[column].str.replace(r'(\.\d{3})\d*', r'\1', regex=True)
    # Convert to timedelta
    final_df3[column] = pd.to_timedelta(final_df3[column])
# Out:
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_1744/1515655406.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df3[column] = final_df3[column].str.replace(r'(\.\d{3})\d*', r'\1', regex=True)
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_1744/1515655406.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df3[column] = pd.to_timedelta(final_df3[column])

# %%
final_df3.head()
# Out:
#    driverId  raceId circuit_location circuit_country  grid_position  \
# 0         3     948        Melbourne       Australia              2
# 1         3     948        Melbourne       Australia              2
# 2         3     948        Melbourne       Australia              2
# 3         3     948        Melbourne       Australia              2
# 4         3     948        Melbourne       Australia              2
#
#    results_position  results_points  results_laps driver_nationality  \
# 0                 1            25.0            57             German
# 1                 1            25.0            57             German
# 2                 1            25.0            57             German
# 3                 1            25.0            57             German
# 4                 1            25.0            57             German
#
#   driver_home  driver_age_atrace constructor_name constructor_home    status  \
# ...

# %%
final_df3.dtypes

# %%
for column in ['q1', 'q2', 'q3','lap_time']:
    final_df3[column] = final_df3[column].dt.total_seconds()

final_df3.head()
# Out:
# /var/folders/q6/0pfb75k55856k8_ms3tldx240000gn/T/ipykernel_1744/339179628.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df3[column] = final_df3[column].dt.total_seconds()
#    driverId  raceId circuit_location circuit_country  grid_position  \
# 0         3     948        Melbourne       Australia              2
# 1         3     948        Melbourne       Australia              2
# 2         3     948        Melbourne       Australia              2
# 3         3     948        Melbourne       Australia              2
# 4         3     948        Melbourne       Australia              2
#
#    results_position  results_points  results_laps driver_nationality  \
# ...

# %%
final_df3.to_csv('Final_Dataset.csv',index=False)
